# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# from backtester.backtester import (
#     sample_polars_spot,
#     sample_polars_rate,
#     sample_polars_option,
#     sample_duckdb_rate,
#     MarketDataProvider,
# )

# import duckdb

# %%
# lf_rate = sample_polars_rate()
# lf_spot = sample_polars_spot()
# lf_option = sample_polars_option()
# lf_rate.show()
# lf_spot.show()
# lf_option.show()

# %%
# with duckdb.connect() as con:
#     lf_rate_duckdb = sample_duckdb_rate(con)
#     lf_rate_duckdb.show()

# %%
# mdp = MarketDataProvider(lf_rate_duckdb, lf_spot, lf_option)
# mdp

# %%
# mdp.lf_priced.collect_schema()
