# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from rng.spot import sample_spot_bars

# %%
exchanges = ["drbt", "okex"]
bases = ["btc", "eth"]
quotes = ["usd", "usdc"]


sample_spot_bars(
    exchanges=exchanges,
    base_assets=bases,
    quote_assets=quotes,
    spread=0.001,
    seed=42,
)
# Out:
# shape: (4_193_280, 7)
# ┌──────────┬──────┬───────┬─────────────────────┬─────────────────────────┬──────────┬──────────┐
# │ exchange ┆ base ┆ quote ┆ time_start          ┆ time_end                ┆ px_bid   ┆ px_ask   │
# │ ---      ┆ ---  ┆ ---   ┆ ---                 ┆ ---                     ┆ ---      ┆ ---      │
# │ str      ┆ str  ┆ str   ┆ datetime[μs, UTC]   ┆ datetime[μs, UTC]       ┆ f64      ┆ f64      │
# ╞══════════╪══════╪═══════╪═════════════════════╪═════════════════════════╪══════════╪══════════╡
# │ drbt     ┆ btc  ┆ usd   ┆ 2025-01-01 00:00:00 ┆ 2025-01-01 00:01:00 UTC ┆ 0.999868 ┆ 1.000971 │
# │          ┆      ┆       ┆ UTC                 ┆                         ┆          ┆          │
# │ drbt     ┆ btc  ┆ usd   ┆ 2025-01-01 00:01:00 ┆ 2025-01-01 00:02:00 UTC ┆ 1.00003  ┆ 1.000761 │
# │          ┆      ┆       ┆ UTC                 ┆                         ┆          ┆          │
# ...
